# %% [markdown]
# # Example: Sensor Calibration
#
# This notebook demonstrates how to use the `calibration.py` module
# to calibrate one or multiple magnetic sensors using CC and SS data.

# %%
# ==========================================================
#  导入模块
# ==========================================================
import numpy as np
import os

from mypaper.calibration import calibrate_all_sensors, predict_field

# 设置随机种子（可选）
np.random.seed(42)

# %%
# ==========================================================
#  加载数据
# ==========================================================
# CC: Calibration cube data, columns: xl, yl, zl, m, n, p
cc = np.loadtxt("../data/cc.txt", delimiter=",")

# SS: Sensor measurements, each sensor 3 columns [Bx, By, Bz]
ss = np.loadtxt("../data/ss.txt", delimiter=",")

# Sensor initial positions
loc = np.loadtxt("../data/loc.txt", delimiter=",")

print("CC shape:", cc.shape)
print("SS shape:", ss.shape)
print("Sensor loc shape:", loc.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 # ==========================================================
#       2 #  加载数据
#       3 # ==========================================================
#       4 # CC: Calibration cube data, columns: xl, yl, zl, m, n, p
# ----> 5 cc = np.loadtxt("../data/cc.txt", delimiter=",")
#       7 # SS: Sensor measurements, each sensor 3 columns [Bx, By, Bz]
#       8 ss = np.loadtxt("../data/ss.txt", delimiter=",")
#
# File D:\software\Anaconda\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
# ==========================================================
#  保存校准参数
# ==========================================================
output_dir = "../para_sensor"
os.makedirs(output_dir, exist_ok=True)

for i, params in enumerate(params_list):
    filename = os.path.join(output_dir, f"para_sensor_{i+1}.txt")
    np.savetxt(filename, params, fmt="%.8f")
    print(f"Sensor {i+1} parameters saved to {filename}")

# %% [markdown]
# # Notes:
# # - `cc.txt`, `ss.txt`, and `loc.txt` should be placed in the `data/` folder.
# # - The calibrated parameters are saved in `para_sensor/`.
# # - You can modify `sensor_idx` to visualize other sensors.
# # - This notebook can be used as a template for reproducibility.
